# %% [markdown]
# # Arbre de décision avec des pinguins
# Cours de Google : prédire l'espèce d'un pinguin à partir de ses caractéristiques.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import sklearn as sk
from sklearn import tree
import matplotlib.pyplot as plt
import graphviz
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.tree import DecisionTreeClassifier, export_graphviz

# %%
path = "penguins.csv"
df = pd.read_csv(path)
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm
# 0    Adelie  Torgersen            39.1           18.7              181.0  \
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# 2         3250.0  FEMALE
# 3            NaN     NaN
# 4         3450.0  FEMALE
# ..           ...     ...
# 339          NaN     NaN
# 340       4850.0  FEMALE
# 341       5750.0    MALE
# 342       5200.0  FEMALE
# 343       5400.0    MALE
#
# [344 rows x 7 columns]

# %% [markdown]
# ## La carte d'identité du dataset :
# Le dataset provient de github et s'appelle simplement "Pinguins".
# Le dataset est composé de 344 données qui représentent des pinguins à l'aide de 7 variables : espèce, île, longueur du bec (mm), largeur du bec (mm), longeur des nageoires (mm), masse (g) et leur sexe.
#
# Le dataset comprend 3 variables catégoriques (espèce, île et sexe) et les 4 autres sont numériques.
#
# Le dataset semble contenir quelques données vides. On les supprimera pour éviter les erreurs.
# Les données numériques seront normalisées.

# %%
#Le dataset contient 2 lignes qui n'ont aucune données pour toutes les variables excepté l'ile et l'espèce.
#Plutôt que de remplir les champs vides ont fait le choix de supprimer les 2 lignes.
df_nettoye = df.dropna(axis=0)
df_nettoye
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm
# 0    Adelie  Torgersen            39.1           18.7              181.0  \
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# 2         3250.0  FEMALE
# 4         3450.0  FEMALE
# 5         3650.0    MALE
# ..           ...     ...
# 338       4925.0  FEMALE
# 340       4850.0  FEMALE
# 341       5750.0    MALE
# 342       5200.0  FEMALE
# 343       5400.0    MALE
#
# [333 rows x 7 columns]

# %%
df = df_nettoye

# %% [markdown]
# ## Statistique sur les données
# L'objectif de cette section est de mieux comprendre le jeu de données pour une meilleure modélisaiton par la suite.

# %%
#Commençons par des informations basiques sur les données numériques (moyenne, écart-type, quartiles, min, max...)
df.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      333.000000     333.000000         333.000000   333.000000
# mean        43.992793      17.164865         200.966967  4207.057057
# std          5.468668       1.969235          14.015765   805.215802
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.500000      15.600000         190.000000  3550.000000
# 50%         44.500000      17.300000         197.000000  4050.000000
# 75%         48.600000      18.700000         213.000000  4775.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %%
#Faisons l'histogramme de chaque espèce
df['species'].hist()
# Out:
# <Axes: >

# %%
len(df["species"])
# Out:
# 333

# %%
def pourcentages(dataset,col):
    total = len(dataset[col])
    print("Voici les statistiques pour chaque valeur de la colonne " + col + ".")
    for value in df[col].unique() :
        n = len(df[df[col]==value])
        pourcentage = round(n/total*100,2)
        print("La valeur " + value + " représente " + str(pourcentage) + "% des valeurs.")

pourcentages(df,"species")
# Out:
# Voici les statistiques pour chaque valeur de la colonne species.
# La valeur Adelie représente 43.84% des valeurs.
# La valeur Chinstrap représente 20.42% des valeurs.
# La valeur Gentoo représente 35.74% des valeurs.

# %%
df['sex'].hist()
# Out:
# <Axes: >

# %%
#Faisons quelques histogrammes pour voir les donnée pour chaque espèce.
def histogramme(dataset):
    for column in dataset.columns:
        if(column != "species"):
            print("Histogramme pour la variable : " + column)
            df.hist(column=column,by="species")

histogramme(df)
# Out:
# Histogramme pour la variable : island
# Histogramme pour la variable : bill_length_mm
# Histogramme pour la variable : bill_depth_mm
# Histogramme pour la variable : flipper_length_mm
# Histogramme pour la variable : body_mass_g
# Histogramme pour la variable : sex

# %% [markdown]
# Faisons des scatters qui nous permettrons peut-être de voir apparaitre des choses

# %%
sns.pairplot(df, x_vars=['bill_length_mm'], y_vars=['bill_depth_mm'], height=5, hue='species', markers=['o', 'v', 's'])

# %%
sns.pairplot(df, x_vars=['flipper_length_mm'], y_vars=['body_mass_g'], height=5, hue='species', markers=['o', 'v', 's'])

# %% [markdown]
# Alors, elles donnent quoi ces données ?
# Tout d'abord, on peut voir qu'il n'y a pas de données "bizarres" (masse négative par exemple).
#
# On peut également remarquer que pour toutes les espèces il y a **autant de mâles que de femelles**.
#
# La **répartition des espèces** représentées dans le dataset n'est **pas équitables**  :
#     L'espèce Adelie représente 43.84% des valeurs.
#     L'espèce Chinstrap représente 20.42% des valeurs.
#     L'espèce Gentoo représente 35.74% des valeurs.
#
# Les pinguins Gentoo et Chinstrap ne sont présents que sur une **île chacun** mais les pinguins Adélie sont sur les 3 îles.
#
# La **longueur des nageoires** (flipper_length) semble être une **bonne variable pour différencier** les Gentoo des autres espèces d'après le 2eme scatter plot.
#
# Le 1er scatter plot nous indique que les 3 espèces peuvent être **séparées à partir des dimensions de leur bec** (bill length and depth).
#
# Enfin, il n'y a **pas de données trop extrêmes** pour les valeurs numériques.

# %% [markdown]
# # Cas avec la normalisation

# %% [markdown]
# ## Préparation des données
# - Normalisation
# - Séparation en datasets d'entrainement et de test

# %% [markdown]
# La normalisation est souvent pratique pour éviter les erreurs liées à la différence de taille entre les valeurs. Nous allons donc l'appliquer ici. Je vais également faire un test sans la normalisation pour voir si cela change quelque chose.

# %%
#Normalisation des données
def normalisationForAll(dataframe):
    #On crée une copie du dataframe passe en argument
    nouveau_df = dataframe
    
    #On récupère les colonnes avec des données non-numériques pour les enlever.
    liste_colonnes_drop = []
    print(liste_colonnes_drop)
    for colonne in dataframe.columns:
        if(nouveau_df[colonne].dtype != np.float64 and nouveau_df[colonne].dtype != np.int64):
            liste_colonnes_drop.append(colonne)
    print(liste_colonnes_drop)
    
    #On enleve les colonnes sans donnees numeriques
    df_a_normaliser = nouveau_df.drop(liste_colonnes_drop, axis=1)
    
    #On applique la normalisation standard
    scaler = StandardScaler()
    donnees_normalisees = scaler.fit_transform(df_a_normaliser)
    df_donnees_normalisees = pd.DataFrame(donnees_normalisees, columns=df_a_normaliser.columns)
    
    #On remplace dans le nouveau dataframe les anciennes colonnes par les colonnes avec les donnes normalisées
    for colonne in liste_colonnes_drop :
        df_donnees_normalisees[colonne] = nouveau_df[colonne]

    return df_donnees_normalisees

df_normalise = normalisationForAll(df).dropna(axis=0)
df_normalise
# Out:
# []
# ['species', 'island', 'sex']
#      bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g species
# 0         -0.896042       0.780732          -1.426752    -0.568475  Adelie  \
# 1         -0.822788       0.119584          -1.069474    -0.506286  Adelie
# 2         -0.676280       0.424729          -0.426373    -1.190361  Adelie
# 4         -0.859415       1.747026          -0.783651    -0.692852  Adelie
# 5         -0.932669       0.323014          -1.426752    -0.723946  Adelie
# ..              ...            ...                ...          ...     ...
# 328        0.587352      -1.762145           0.931283     0.892957  Gentoo
# 329        0.514098      -1.457000           1.002739     0.799674  Gentoo
# 330        1.173384      -0.744994           1.502928     1.919069  Gentoo
# 331        0.221082      -1.202712           0.788372     1.234995  Gentoo
# 332        1.081817      -0.541564           0.859828     1.483749  Gentoo
#
#         island     sex
# 0    Torgersen    MALE
# 1    Torgersen  FEMALE
# 2    Torgersen  FEMALE
# 4    Torgersen  FEMALE
# 5    Torgersen    MALE
# ..         ...     ...
# 328     Biscoe  FEMALE
# 329     Biscoe    MALE
# 330     Biscoe  FEMALE
# 331     Biscoe    MALE
# 332     Biscoe  FEMALE
#
# [324 rows x 7 columns]

# %%
df_normalise = df_normalise.reset_index()
df_normalise
# Out:
#      index  bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# 0        0       -0.896042       0.780732          -1.426752    -0.568475  \
# 1        1       -0.822788       0.119584          -1.069474    -0.506286
# 2        2       -0.676280       0.424729          -0.426373    -1.190361
# 3        4       -0.859415       1.747026          -0.783651    -0.692852
# 4        5       -0.932669       0.323014          -1.426752    -0.723946
# ..     ...             ...            ...                ...          ...
# 319    328        0.587352      -1.762145           0.931283     0.892957
# 320    329        0.514098      -1.457000           1.002739     0.799674
# 321    330        1.173384      -0.744994           1.502928     1.919069
# 322    331        0.221082      -1.202712           0.788372     1.234995
# 323    332        1.081817      -0.541564           0.859828     1.483749
#
#     species     island     sex
# 0    Adelie  Torgersen    MALE
# 1    Adelie  Torgersen  FEMALE
# 2    Adelie  Torgersen  FEMALE
# 3    Adelie  Torgersen  FEMALE
# 4    Adelie  Torgersen    MALE
# ..      ...        ...     ...
# 319  Gentoo     Biscoe  FEMALE
# 320  Gentoo     Biscoe    MALE
# 321  Gentoo     Biscoe  FEMALE
# 322  Gentoo     Biscoe    MALE
# 323  Gentoo     Biscoe  FEMALE
#
# [324 rows x 8 columns]

# %%
#Finalement pour utiliser un arbre de décision il ne faut que des données numériques donc on va appliquer le principe de dummification
def dummification(dataframe,colonnes):
    df = dataframe
    for colonne in colonnes :
        df_dum = pd.get_dummies(df[colonne])
        df_dumconcat = pd.concat([df,df_dum],axis=1)
        df = df_dumconcat.drop(columns=colonne,axis=1)
    return df

df_a_indexer = dummification(df_normalise,["island","sex"]).drop(columns="index",axis=1)
df_a_indexer
# Out:
#      bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g species
# 0         -0.896042       0.780732          -1.426752    -0.568475  Adelie  \
# 1         -0.822788       0.119584          -1.069474    -0.506286  Adelie
# 2         -0.676280       0.424729          -0.426373    -1.190361  Adelie
# 3         -0.859415       1.747026          -0.783651    -0.692852  Adelie
# 4         -0.932669       0.323014          -1.426752    -0.723946  Adelie
# ..              ...            ...                ...          ...     ...
# 319        0.587352      -1.762145           0.931283     0.892957  Gentoo
# 320        0.514098      -1.457000           1.002739     0.799674  Gentoo
# 321        1.173384      -0.744994           1.502928     1.919069  Gentoo
# 322        0.221082      -1.202712           0.788372     1.234995  Gentoo
# 323        1.081817      -0.541564           0.859828     1.483749  Gentoo
#
#      Biscoe  Dream  Torgersen  FEMALE   MALE
# 0     False  False       True   False   True
# 1     False  False       True    True  False
# 2     False  False       True    True  False
# 3     False  False       True    True  False
# 4     False  False       True   False   True
# ..      ...    ...        ...     ...    ...
# 319    True  False      False    True  False
# 320    True  False      False   False   True
# 321    True  False      False    True  False
# 322    True  False      False   False   True
# 323    True  False      False    True  False
#
# [324 rows x 10 columns]

# %%
df_a_indexer.columns
# Out:
# Index(['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g',
#        'species', 'Biscoe', 'Dream', 'Torgersen', 'FEMALE', 'MALE'],
#       dtype='object')

# %%
#Réorganisons les colonnes pour pouvoir faire la séparation entre les données d'entrainement et de test
df_ordonne = df_a_indexer.reindex(columns= ['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g', 'Biscoe', 'Dream', 'Torgersen', 'FEMALE', 'MALE',"species"])
df_ordonne
# Out:
#      bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  Biscoe
# 0         -0.896042       0.780732          -1.426752    -0.568475   False  \
# 1         -0.822788       0.119584          -1.069474    -0.506286   False
# 2         -0.676280       0.424729          -0.426373    -1.190361   False
# 3         -0.859415       1.747026          -0.783651    -0.692852   False
# 4         -0.932669       0.323014          -1.426752    -0.723946   False
# ..              ...            ...                ...          ...     ...
# 319        0.587352      -1.762145           0.931283     0.892957    True
# 320        0.514098      -1.457000           1.002739     0.799674    True
# 321        1.173384      -0.744994           1.502928     1.919069    True
# 322        0.221082      -1.202712           0.788372     1.234995    True
# 323        1.081817      -0.541564           0.859828     1.483749    True
#
#      Dream  Torgersen  FEMALE   MALE species
# 0    False       True   False   True  Adelie
# 1    False       True    True  False  Adelie
# 2    False       True    True  False  Adelie
# 3    False       True    True  False  Adelie
# 4    False       True   False   True  Adelie
# ..     ...        ...     ...    ...     ...
# 319  False      False    True  False  Gentoo
# 320  False      False   False   True  Gentoo
# 321  False      False    True  False  Gentoo
# 322  False      False   False   True  Gentoo
# 323  False      False    True  False  Gentoo
#
# [324 rows x 10 columns]

# %%
train_df = df_ordonne.sample(frac=0.8)
test_df = df_ordonne.drop(train_df.index)

train_df_Y = train_df['species']
test_df_Y = test_df['species']

train_df_X = train_df.drop("species",axis=1)
test_df_X = test_df.drop("species",axis=1)

train_df_X
# Out:
#      bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  Biscoe
# 81        -0.804474       0.475587          -1.069474     0.302166   False  \
# 292        0.642293      -1.609573           0.788372     0.830769    True
# 217        0.514098      -0.897567           1.002739     1.172806    True
# 257        0.825428      -1.558715           1.360017     1.359372    True
# 175        0.642293      -0.185561          -0.140551    -0.381909   False
# ..              ...            ...                ...          ...     ...
# 201        0.514098      -0.338134          -0.855107    -0.692852   False
# 216       -0.126875      -1.914718           0.574005     0.239977    True
# 143        0.257709       0.780732          -0.926562    -0.848323   False
# 283        0.221082      -0.388992           1.574384     2.167824    True
# 40        -0.712907       0.882447          -0.926562     0.115600   False
#
#      Dream  Torgersen  FEMALE   MALE
# 81    True      False    True  False
# 292  False      False    True  False
# 217  False      False   False   True
# 257  False      False   False   True
# 175   True      False   False   True
# ..     ...        ...     ...    ...
# 201   True      False   False   True
# 216  False      False    True  False
# 143   True      False   False   True
# 283  False      False   False   True
# 40    True      False   False   True
#
# [259 rows x 9 columns]

# %% [markdown]
# ## Modélisation avec normalisation

# %% [markdown]
# Commençons par une simple modélisation pour comprendre ce qu'il se passe. Nous nous occuperons des hyperparamètres ensuite.

# %%
tree_classifier = DecisionTreeClassifier(max_depth=3,
random_state=42)
tree_classifier.fit(train_df_X, train_df_Y)
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=42)

# %%
y_pred = tree_classifier.predict(test_df_X)
y_pred
# Out:
# array(['Adelie', 'Adelie', 'Adelie', 'Chinstrap', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Chinstrap', 'Chinstrap', 'Chinstrap', 'Chinstrap', 'Chinstrap',
#        'Chinstrap', 'Chinstrap', 'Chinstrap', 'Chinstrap', 'Adelie',
#        'Chinstrap', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo',
#        'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo',
#        'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo',
#        'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo',
#        'Gentoo'], dtype=object)

# %%
sk.metrics.multilabel_confusion_matrix(test_df_Y,y_pred)
# Out:
# array([[[34,  1],
#         [ 1, 29]],
#
#        [[53,  1],
#         [ 1, 10]],
#
#        [[41,  0],
#         [ 0, 24]]], dtype=int64)

# %%
sk.metrics.accuracy_score(test_df_Y,y_pred)
# Out:
# 0.9692307692307692

# %%
sk.metrics.fbeta_score(test_df_Y,y_pred,average=None,beta=1)
# Out:
# array([0.96666667, 0.90909091, 1.        ])

# %%
def afficherArbreDecision(class_names,features_names,arbre):
    fig, ax = plt.subplots(figsize=(12, 12))
    tree.plot_tree(arbre, feature_names=feature_names, class_names=class_names, filled=True, ax=ax)
    plt.show()
class_names = ["Adelie","Gentoo","Chinstrap"]
feature_names = ["bill_length_mm","bill_depth_mm","flipper_length_mm","body_mass_g","Biscoe","Dream","Torgersen","FEMALE","MALE"]
afficherArbreDecision(class_names,feature_names,tree_classifier)

# %%
def BestHyperparameters(trainX,trainY,testX,testY,min_example,depth):
    best_accuracy = 0
    best_min_example = 0
    best_depth = 0
    best_criterion = ""
    #On va tester toutes les combinaisons possibles :
    for criterion in ["gini","entropy"]:
        for example in min_example:
            for profondeur in depth:
                #On créer l'arbre
                arbre = DecisionTreeClassifier(criterion=criterion,min_samples_leaf=example,max_depth=profondeur)
                arbre.fit(trainX, trainY)
                #On calcule la prédiction et l'accuracy associée
                predictionY = arbre.predict(testX)
                accuracy = sk.metrics.accuracy_score(testY,predictionY)
                #On compare
                if accuracy>best_accuracy :
                    best_accuracy = accuracy
                    best_min_example = example
                    best_depth = profondeur
                    best_criterion= criterion
                
    return (best_accuracy,best_min_example,best_depth,best_criterion)

# %%
BestHyperparameters(train_df_X,train_df_Y,test_df_X,test_df_Y,[2,3,5],[1,2,3,4,5,6,10])
# Out:
# (1.0, 2, 4, 'gini')

# %% [markdown]
# Les meilleurs hyperparamètres sont probablement : 2 exemples minimum par feuille, 4 de profondeur en utilisant Gini. Cela correspond à l'arbre suivant :

# %%
arbre_final_normal = DecisionTreeClassifier(criterion="gini",min_samples_leaf=2,max_depth=4)
arbre_final_normal.fit(train_df_X,train_df_Y)
class_names = ["Adelie","Gentoo","Chinstrap"]
feature_names = ["bill_length_mm","bill_depth_mm","flipper_length_mm","body_mass_g","Biscoe","Dream","Torgersen","FEMALE","MALE"]
afficherArbreDecision(class_names,feature_names,arbre_final_normal)

# %% [markdown]
# # Cas sans normalisation

# %%
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm
# 0    Adelie  Torgersen            39.1           18.7              181.0  \
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# 2         3250.0  FEMALE
# 4         3450.0  FEMALE
# 5         3650.0    MALE
# ..           ...     ...
# 338       4925.0  FEMALE
# 340       4850.0  FEMALE
# 341       5750.0    MALE
# 342       5200.0  FEMALE
# 343       5400.0    MALE
#
# [333 rows x 7 columns]

# %%
df_dummification= dummification(df,["island","sex"])
df_dummification
# Out:
#     species  bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# 0    Adelie            39.1           18.7              181.0       3750.0  \
# 1    Adelie            39.5           17.4              186.0       3800.0
# 2    Adelie            40.3           18.0              195.0       3250.0
# 4    Adelie            36.7           19.3              193.0       3450.0
# 5    Adelie            39.3           20.6              190.0       3650.0
# ..      ...             ...            ...                ...          ...
# 338  Gentoo            47.2           13.7              214.0       4925.0
# 340  Gentoo            46.8           14.3              215.0       4850.0
# 341  Gentoo            50.4           15.7              222.0       5750.0
# 342  Gentoo            45.2           14.8              212.0       5200.0
# 343  Gentoo            49.9           16.1              213.0       5400.0
#
#      Biscoe  Dream  Torgersen  FEMALE   MALE
# 0     False  False       True   False   True
# 1     False  False       True    True  False
# 2     False  False       True    True  False
# 4     False  False       True    True  False
# 5     False  False       True   False   True
# ..      ...    ...        ...     ...    ...
# 338    True  False      False    True  False
# 340    True  False      False    True  False
# 341    True  False      False   False   True
# 342    True  False      False    True  False
# 343    True  False      False   False   True
#
# [333 rows x 10 columns]

# %%
df_propre = df_dummification.reset_index().reindex(columns=['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g', 'Biscoe', 'Dream', 'Torgersen', 'FEMALE', 'MALE',"species"])
df_propre
# Out:
#      bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  Biscoe
# 0              39.1           18.7              181.0       3750.0   False  \
# 1              39.5           17.4              186.0       3800.0   False
# 2              40.3           18.0              195.0       3250.0   False
# 3              36.7           19.3              193.0       3450.0   False
# 4              39.3           20.6              190.0       3650.0   False
# ..              ...            ...                ...          ...     ...
# 328            47.2           13.7              214.0       4925.0    True
# 329            46.8           14.3              215.0       4850.0    True
# 330            50.4           15.7              222.0       5750.0    True
# 331            45.2           14.8              212.0       5200.0    True
# 332            49.9           16.1              213.0       5400.0    True
#
#      Dream  Torgersen  FEMALE   MALE species
# 0    False       True   False   True  Adelie
# 1    False       True    True  False  Adelie
# 2    False       True    True  False  Adelie
# 3    False       True    True  False  Adelie
# 4    False       True   False   True  Adelie
# ..     ...        ...     ...    ...     ...
# 328  False      False    True  False  Gentoo
# 329  False      False    True  False  Gentoo
# 330  False      False   False   True  Gentoo
# 331  False      False    True  False  Gentoo
# 332  False      False   False   True  Gentoo
#
# [333 rows x 10 columns]

# %%
train = df_propre.sample(frac=0.8)
test = df_propre.drop(train_df.index)

trainY = train['species']
testY = test['species']

trainX = train.drop("species",axis=1)
testX = test.drop("species",axis=1)

trainX
# Out:
#      bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  Biscoe
# 309            46.9           14.6              222.0       4875.0    True  \
# 49             41.4           18.6              191.0       3700.0    True
# 304            45.5           14.5              212.0       4750.0    True
# 44             39.6           17.7              186.0       3500.0    True
# 80             36.3           19.5              190.0       3800.0   False
# ..              ...            ...                ...          ...     ...
# 77             35.1           19.4              193.0       4200.0   False
# 284            48.2           15.6              221.0       5100.0    True
# 197            51.4           19.0              201.0       3950.0   False
# 214            46.1           13.2              211.0       4500.0    True
# 183            52.0           20.7              210.0       4800.0   False
#
#      Dream  Torgersen  FEMALE   MALE
# 309  False      False    True  False
# 49   False      False   False   True
# 304  False      False    True  False
# 44   False      False    True  False
# 80    True      False   False   True
# ..     ...        ...     ...    ...
# 77   False       True   False   True
# 284  False      False   False   True
# 197   True      False   False   True
# 214  False      False    True  False
# 183   True      False   False   True
#
# [266 rows x 9 columns]

# %% [markdown]
# ## Modélisation sans normalisation

# %%
buisson = DecisionTreeClassifier(max_depth=3,
random_state=42)
buisson.fit(trainX, trainY)
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=42)

# %%
class_names = ["Adelie","Gentoo","Chinstrap"]
feature_names = ["bill_length_mm","bill_depth_mm","flipper_length_mm","body_mass_g","Biscoe","Dream","Torgersen","FEMALE","MALE"]
afficherArbreDecision(class_names,feature_names,buisson)

# %%
BestHyperparameters(trainX,trainY,testX,testY,[2,3,5],[1,2,3,4,5,6,10])
# Out:
# (1.0, 2, 4, 'gini')

# %%
meilleur_arbre = DecisionTreeClassifier(max_depth=4,min_samples_leaf=2,criterion="gini")
meilleur_arbre.fit(trainX, trainY)
afficherArbreDecision(class_names,feature_names,meilleur_arbre)

# %%
predictionY = meilleur_arbre.predict(testX)
predictionY
# Out:
# array(['Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Chinstrap', 'Chinstrap', 'Chinstrap', 'Chinstrap', 'Chinstrap',
#        'Chinstrap', 'Chinstrap', 'Chinstrap', 'Chinstrap', 'Chinstrap',
#        'Chinstrap', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo',
#        'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo',
#        'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo',
#        'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo',
#        'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo',
#        'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo'], dtype=object)

# %%
accuracy = sk.metrics.accuracy_score(testY,predictionY)
accuracy
# Out:
# 1.0

# %%
f1_score = sk.metrics.f1_score(testY,predictionY,average=None)
f1_score
# Out:
# array([1., 1., 1.])

# %% [markdown]
# Dans la mesure où l'on a déjà une accuracy de 100% ou de 98% dans nos cas nous n'allons pas voir d'algorithme ensemblistes qui rajouterai de la complexité et du temps de calcul sans permettre de gagner en qualité de prédiction.
