# %%
#Importation
import pickle
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# On ramene les données du prétraitement du dataframe
df = pd.read_pickle("../PICKLE/dataframe_labelise.pkl")
df
# Out:
#       No DESIGNATION  COMMENTAIRE DE SIG
# 0          299568158                 NaN  \
# 1          297892193                 NaN
# 2          297897767                 NaN
# 3          223370510                 NaN
# 4          299556603                 NaN
# ...              ...                 ...
# 4183       223275005                 NaN
# 4184       296611510                 NaN
# 4185       223309738                 NaN
# 4186       298170718                 NaN
# 4187       298170734                 NaN
#
#                                             COMMENTAIRE
# 0     # Obtenu MARCHAND CHRISTOPHE le 26/04/2023 a 1...  \
# 1     /DMS/#PTO_existante#-#Malfa on PLP non detect ...
# 2     /DMS/#PTO_non existante#/Mohand ok raccordemen...
# 3     /DMS/#PTO_non existante#/Installation complete...
# 4     /DMS/#PTO_existante#-#Malfa on PLP non detect ...
# ...                                                 ...
# 4183                                                NaN
# 4184  /DMS/#PTO_existante#-#Malfacon PLP non detecte...
# 4185  /DMS/#PTO_non existante#/Raccordement effectue...
# 4186  /DMS/#PTO_non existante#/Raccordement en chamb...
# 4187  /DMS/#PTO_non existante#/Raccordement en aerie...
#
#                                               BLOC NOTE
# 0                                                   NaN  \
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4183  Merci de cleturer le rendez vous du client car...
# 4184                                                NaN
# 4185                                                NaN
# 4186                                                NaN
# 4187                                                NaN
#
#                                          COMMLITIGEPIDI  Reussite
# 0                                                     \     False
# 1     \\$GM$ Un rdv a ete repris par le technicien p...      True
# 2     \\$GM$ CP Obtenu cliente le 13/04  Le client a...      True
# 3                                                     \      True
# 4                                                     \      True
# ...                                                 ...       ...
# 4183  \\$GM$ Un rdv a ete repris par le tehcnicien p...      True
# 4184                                                  \      True
# 4185                                                  \      True
# 4186  \\$GM$ Obtenu M. Couchevellou au 0658359425 le...      True
# 4187                                                  \      True
#
# [4188 rows x 6 columns]

# %% [markdown]
# ## 3 - Nettoyage des textes
# Cette partie a pour but de mettre au propre les commentaires pour avoir un dataframe propre.
# Tout d'abord on a codé plusieurs fonctions pour enlever la ponctuation, enlever les codes de relève, mettre en minscule, modifier les abbréviation et les fautes de frappes communes...
#
# En suite j'ai tout récupérer et mis dans un data frame avec uniquement le numéro d'identification, la réussite de l'opération et la liste des commentaires.

# %%
#Fonction pour enlever les code de relève des textes.
labels = ["rrc","dms","pad","tvc","etu","rmc","rmf","ann","ort","anc","pbc","reo"]
def enleve_releve_liste(commentaires):
    commentaires_propres = []
    for commentaire in commentaires :
        for label in labels :
            commentaire = commentaire.replace(label,'')
        commentaires_propres.append(commentaire)
    
    return commentaires_propres

# %%
#Fonction pour enlever les string vides d'une liste de strings
def supprimer_string_vide(liste):
    liste2 = []
    for i in liste :
        if i != "":
            liste2.append(i)
    return liste2

# %%
#Fonction pour remplacer les acronymes des techniciens

#Créons un dictionnaire
dico_mots = {"=":"",".":"","_":" ","-":" ","/":" ","$":"","#":"","teste":"test","nimporte":"n'importe","cable":"câble","c ble":"câble","tranch e":"tranchée","tranchee":"tranchée","tranche":"tranchée","tiquetage":"étiquetage","malfa":"malfaçon","pb":"point de branchement","mevo":"message vocal","pto":"point de terminaison optique","pto_non":"point de terminaison optique non","ligible":"éligible","racc":"raccordement","fa ade":"facade","propi taire":"propriétaire","detect e":"détectée"}
dico_mots
# Out:
# {'=': '',
#  '.': '',
#  '_': ' ',
#  '-': ' ',
#  '/': ' ',
#  '$': '',
#  '#': '',
#  'teste': 'test',
#  'nimporte': "n'importe",
#  'cable': 'câble',
#  'c ble': 'câble',
#  'tranch e': 'tranchée',
#  'tranchee': 'tranchée',
#  'tranche': 'tranchée',
#  'tiquetage': 'étiquetage',
#  'malfa': 'malfaçon',
#  'pb': 'point de branchement',
#  'mevo': 'message vocal',
#  'pto': 'point de terminaison optique',
#  'pto_non': 'point de terminaison optique non',
#  'ligible': 'éligible',
#  'racc': 'raccordement',
#  'fa ade': 'facade',
#  'propi taire': 'propriétaire',
#  'detect e': 'détectée'}

# %%
#Fonction pour appliquer les changements du dictionnaire
def anti_acronymes_grammar(liste):
    liste_retour = []
    for e in liste:
        for key,value in dico_mots.items():
            e = e.replace(key,value)
        liste_retour.append(e)
    
    return liste_retour

# %%
def lower_case(liste):
    return [e.lower() for e in liste]

# %%
def sans_numero_ponctuation(liste):
    liste_rendu = []
    pattern = r'\d+'
    for text in liste :
        text = re.sub('\[.*?\]', '', text)
        text = re.sub('\w*\d\w*', '', text)
        text = re.sub(pattern,'',text)
        text = re.sub('[‘’“”…]', '', text)
        text = re.sub('\n', '', text)
        liste_rendu.append(text)
    return liste_rendu

liste = ["kooz","90 FE","9"]
sans_numero_ponctuation(liste)
# Out:
# ['kooz', ' FE', '']

# %%
#La fonction regroupant tous les nettoyages
def liste_propre(liste):
    #On met tout en minuscule
    liste = lower_case(liste)
    #On enleve les codes de releve
    liste = enleve_releve_liste(liste)
    #On enleve les signes et on remplaces les accronymes et erreurs principales de frappe
    liste = anti_acronymes_grammar(liste)
    #On enleve les nombres et la ponctuation
    liste = sans_numero_ponctuation(liste)
    return liste

# %%
#Récupération de tous les commentaires dans une liste de commentaires
def transformation_colonnes_commentaires(dataframe,colonnes,separateur):
    #Création de la liste
    colonne_commentaires = []
    
    #On va procéder ligne à ligne
    for i in dataframe.index :
        #On crée la liste des commentaires pour la ligne i
        commentaires_i = []
        
        #Pour chaque colonne on split le commentaire et on l'ajoute à la liste des commentaires de la ligne i.
        for colonne in colonnes :
            #On récupère le commentaire
            texte = dataframe.at[i,colonne]
            #S'il y en a un, on applique le séparateur et on rend ça propre
            if isinstance(texte, str) :
                commentaires_i = commentaires_i + liste_propre(texte.split(separateur))
         
        colonne_commentaires.append(commentaires_i)
        
    return colonne_commentaires

# %%
print(transformation_colonnes_commentaires(df,["COMMENTAIRE DE SIG","COMMENTAIRE","BLOC NOTE","COMMLITIGEPIDI"],'\\'))
# Out:
# [[' obtenu marchand christophe le    a  le client repe son rdv car n a pas encore termine les   il va contacter orange pour fixer un nouveau rdv ', '', ''], ['  point de terminaison optique existante malfaçon on plp non détectée  point de terminaison optique existante brassage au niveau du pm ont ok dae ok ', '', '', 'gm un rdv a ete repris par le technicien pour le   a partir de  apsp ', ''], ['  point de terminaison optique non existante mohand ok raccordementordement pavillon en aerien ok point de terminaison optique pose au salon a la demande du client val pm  val point de terminaison optique  delc ok  dae ok ', '', '', "gm cp obtenu cliente le    le client a bien compris les travaux a realiser et nous recontactera pour reprendre rdv des travaux finisapsm poser une gaine entre l'arrivee interieure (pavillon) et l'emplacement souhaite de la prise fibre", 'gm obtenu clt le   au  repris rdv le   a partir de  apil', "gm cp obtenu cliente le    le client a bien compris les travaux a realiser et nous recontactera pour reprendre rdv des travaux finisapsm poser une gaine entre l'arrivee interieure (pavillon) et l'emplacement souhaite de la prise fibre", 'gm rv    obtenu client au  le    a :  rdv repris pour le   a partir de :  aphb', ''], ['  point de terminaison optique non existante installation complete pavillon ok passage de câble souterrain ok  dae ok ', '', ''], ['  point de terminaison optique existante malfaçon on plp non détectée  pm: t   decharge :  dae ok ', '', ''], ['  point de terminaison optique non existante installation immeuble complete ok dae ok ', '', ''], ['  point de terminaison optique existante malfaçon on plp non détectée  moby hs le t est et ok le client a teins la boxe route optique ok pas pu faire arriver sur site moby hs pas pu cl turer aussi  dae ko moby hs', 'plp non detecte en commande mais suspecte  si presence point de terminaison optique  utiliser emutation pour muter  si pas de point de terminaison optique  utiliser emutation pour creer point de terminaison optique puis mutersi pas possible appeler appui a chaud  ou   precisez lors de la cloture si point de terminaison optique a ete trouvee', '', ''], ['  point de terminaison optique existante malfaçon on plp détectée câble non conforme  reprise point de terminaison optique voir photo   dae ok ', 'plp non detecte en commande mais suspecte  si presence point de terminaison optique  utiliser emutation pour muter  si pas de point de terminaison optique  utiliser emutation pour creer point de terminaison optique puis mutersi pas possible appeler appui a chaud  ou   precisez lors de la cloture si point de terminaison optique a ete trouvee', '', ''], ['obtenu pian claudine au  le    a :   le clt doit uler le rdv car l adresse correct est  allee du presbytere  plorec sur arguenonpas eéligiblend:', '', ''], ['  point de terminaison optique non existante raccordement aerien  tout service ok point de terminaison optique installer au salon client satisfait  dae ok ', '', ''], ['ele', '', 'obtenu client le   pour reprise de rdv client na a pas encore effectue ses travaux apep gm cp envoye sms au  le   a  pour reprendre nouveau rdv des  fini + laisse message vocal pour infos travaux  apsm  gem litige: ra refus passage en apparent dans les par', '', '', 'gm cp envoye sms au  le    a  pour reprendre nouveau rdv des  fini + laisse message vocal pour infos travaux  apsm  gem litige: ra refus passage en apparent dans les parties communes  bloquage cheminement point de terminaison optique point de branchemento  partie privative  gaine technique inaccessible les c cble dsl ne bougent pas   la cliente est lo', 'gmgm cp envoye sms au  le    a  pour reprendre nouveau rdv des  fini + laisse message vocal pour infos travaux  apsm  gem litige: ra refus passage en apparent dans les parties communes  bloquage cheminement point de terminaison optique point de branchemento  partie privative  gaine technique inaccessible les c cble dsl ne bougent pas   la cliente es', '', ''] ...

# %%
df["COMMENTAIRES"] = transformation_colonnes_commentaires(df,["COMMENTAIRE DE SIG","COMMENTAIRE","BLOC NOTE","COMMLITIGEPIDI"],'\\')
df = df.drop(columns=["COMMENTAIRE DE SIG","COMMENTAIRE","BLOC NOTE","COMMLITIGEPIDI"])

# %%
def drop_pas_comm(dataframe):
    for index in dataframe.index:
        if dataframe.loc[index,"COMMENTAIRES"] == []:
            dataframe = dataframe.drop(dataframe.index[index])
    return dataframe
df = drop_pas_comm(df)

# %%
df
# Out:
#       No DESIGNATION  Reussite
# 0          299568158     False  \
# 1          297892193      True
# 2          297897767      True
# 3          223370510      True
# 4          299556603      True
# ...              ...       ...
# 4183       223275005      True
# 4184       296611510      True
# 4185       223309738      True
# 4186       298170718      True
# 4187       298170734      True
#
#                                            COMMENTAIRES
# 0     [ obtenu marchand christophe le    a  le clien...
# 1     [  point de terminaison optique existante malf...
# 2     [  point de terminaison optique non existante ...
# 3     [  point de terminaison optique non existante ...
# 4     [  point de terminaison optique existante malf...
# ...                                                 ...
# 4183  [merci de clrer le rendez vous du client car i...
# 4184  [  point de terminaison optique existante malf...
# 4185  [  point de terminaison optique non existante ...
# 4186  [  point de terminaison optique non existante ...
# 4187  [  point de terminaison optique non existante ...
#
# [4188 rows x 3 columns]

# %%
df.to_pickle("../PICKLE/df_liste_commentaires.pkl")
