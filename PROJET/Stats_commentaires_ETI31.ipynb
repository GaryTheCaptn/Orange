# %% [markdown]
# ## Importation

# %%
#Proportion de réussite et d'échecs
def proportions():
    count_reussite = df["Reussite"].value_counts(normalize=True)*100
    # Création d'un histogramme des pourcentages
    count_reussite.plot(kind='bar')

    # Ajout d'un titre et d'étiquettes d'axe
    plt.title('Histogramme des pourcentages par valeur')
    plt.xlabel('Valeur')
    plt.ylabel('Pourcentage')

    # Affichage du graphique
    plt.show()
    print(count_reussite)
    return
proportions()
# Out:
# Reussite
# True     88.013372
# False    11.986628
# Name: proportion, dtype: float64

# %% [markdown]
# On va faire des statistiques sur 3 ensembles de données : les échecs, les réussites et les 2 mis ensemble.

# %%
df_echec =  df[df["Reussite"]==False]
df_echec
# Out:
#       No DESIGNATION  Reussite
# 0          299568158     False  \
# 8          296415177     False
# 11         223449565     False
# 12         296947056     False
# 23         296142912     False
# ...              ...       ...
# 4130       298937060     False
# 4149       297452718     False
# 4160       297897749     False
# 4161       299880324     False
# 4164       296471202     False
#
#                                            COMMENTAIRES
# 0     [' obtenu marchand christophe le    a  le clie...
# 8     ['obtenu pian claudine au  le    a :   le clt ...
# 11    ['cac=ouigps=dn=point de branchementr= de bran...
# 12    ['suite a plusieurs reles aucun retour de la p...
# 23               ['pas de contact client pour fixer  ']
# ...                                                 ...
# 4130  ['   probleme d adresse bonne adresse  le roz ...
# 4149  ['cac=ouigps=dn=point de branchementr= de bran...
# 4160  ['  cli     client  dae na non eéligible au dae']
# 4161  ['apres plusieurs reles pas de retour client d...
# 4164  ['obtenu louet stephane au  le    a :   souhai...
#
# [502 rows x 3 columns]

# %%
len(df_echec.loc[0,"COMMENTAIRES"])
# Out:
# 146

# %%
df_echec.dtypes
# Out:
# No DESIGNATION     int64
# Reussite            bool
# COMMENTAIRES      object
# dtype: object

# %% [markdown]
# ## Nombre de commentaires et leur longueur moyenne

# %%
def nombres_de_commentaires(dataframe):
    ensemble = dataframe["COMMENTAIRES"]
    nombre_commentaires = []
    somme = 0
    for commentaires in ensemble:
        i = len(commentaires)
        somme = somme + i
        nombre_commentaires.append(i)
    moyenne = somme/len(ensemble)
    return (moyenne,nombre_commentaires)

# %%
def longueur_moyenne_commentaires(dataframe):

# %% [markdown]
# ### Ensemble

# %%
nombres_de_commentaires(df_echec)
# Out:
# (293.36653386454185,
#  [146,
#   148,
#   864,
#   415,
#   38,
#   154,
#   85,
#   68,
#   312,
#   398,
#   228,
#   125,
#   89,
#   165,
#   245,
#   586,
#   544,
#   123,
#   77,
#   293,
#   280,
#   495,
#   469,
#   121,
#   169,
#   217,
#   454,
#   214,
#   99,
#   109,
#   94,
#   155,
#   228,
#   287,
#   363,
#   278,
#   70,
#   501,
#   407,
#   217,
#   66,
#   209,
#   356,
#   429,
#   720,
#   165,
#   144,
#   465,
#   425,
#   222,
#   282,
#   529,
#   430,
#   694,
#   152,
#   301,
#   457,
#   79,
#   292,
#   181,
#   331,
#   609,
#   481,
#   665,
#   69,
#   462,
#   104,
#   105,
#   507,
#   94,
#   116,
#   63,
#   379,
#   688,
#   113,
#   531,
#   317,
#   59,
#   68,
#   125,
#   193,
#   121,
#   471,
#   79,
#   111,
#   160,
#   195,
#   387,
#   93,
#   501,
#   478,
#   223,
#   580,
#   106,
#   160,
#   159,
#   98,
#   404,
#   608,
#   219,
#   154,
#   149,
#   472,
#   418,
#   46,
#   271,
#   70,
#   63,
#   98,
#   414,
#   90,
#   95,
#   642,
#   154,
#   152,
#   505,
#   84,
#   222,
#   384,
#   109,
#   59,
#   139,
#   381,
#   496,
#   49,
#   86,
#   511,
#   571,
#   703,
#   1468,
#   75,
#   262,
#   433,
#   288,
#   170,
#   135,
#   118,
#   73,
#   330,
#   166,
#   33,
#   88,
#   233,
#   44,
#   574,
#   58,
#   185,
#   590,
#   493,
#   121,
#   110,
#   101,
#   342,
#   473,
#   292,
#   90,
#   487,
#   226,
#   80,
#   290,
#   121,
#   151,
#   161,
#   418,
#   125,
#   371,
#   53,
#   549,
#   273,
#   91,
#   285,
#   99,
#   84,
#   75,
#   108,
#   497,
#   262,
#   329,
#   100,
#   205,
#   88,
#   98,
#   86,
#   423,
#   108,
#   96,
#   798,
#   33,
#   72,
#   258,
#   229,
#   249,
#   74,
#   93,
#   518,
#   448,
#   99,
#   125,
#   478,
#   34,
#   94,
#   93,
#   144,
#   208,
#   387,
#   279,
#   357,
#   197,
#   400,
#   66,
#   78,
#   268,
#   330,
#   446,
#   204,
#   96,
#   717,
#   683,
#   503,
#   297,
#   84,
#   188,
#   709,
#   514,
#   234,
#   173,
#   258,
#   58,
#   923,
#   253,
#   168,
#   435,
#   391,
#   346,
#   78,
#   282,
#   1090,
#   285,
#   174,
#   113,
#   105,
#   172,
#   589,
#   107,
#   438,
#   90,
#   382,
#   201,
#   91,
#   356,
#   242,
#   113,
#   537,
#   54,
#   1111,
#   568,
#   366,
#   329,
#   113,
#   77,
#   42,
#   53,
#   304,
#   43,
#   545,
#   154,
#   90,
#   132,
#   290,
#   557,
#   316,
#   325,
#   176,
#   152,
#   467,
#   103,
#   346,
#   152,
#   125,
#   341,
#   67,
#   360,
#   334,
#   393,
#   1313,
#   60,
#   548,
#   356,
#   171,
#   257,
#   315,
#   325,
#   700,
#   361,
#   99,
#   156,
#   224,
#   123,
#   628,
#   222,
#   320,
#   142,
#   74,
#   596,
#   248,
#   217,
#   347,
#   853,
#   266,
#   355,
#   194,
#   197,
#   209,
#   529,
#   531,
#   184,
#   392,
#   296,
#   184,
#   120,
#   94,
#   56,
#   69,
#   215,
#   284,
#   584,
#   317,
#   330,
#   625,
#   279,
#   147,
#   97,
#   431,
#   165,
#   501,
#   553,
#   667,
#   343,
#   290,
#   270,
#   599,
#   207,
#   754,
#   205,
#   90,
#   596,
#   296,
#   66,
#   228,
#   385,
#   325,
#   328,
#   363,
#   255,
#   33,
#   69,
#   84,
#   479,
#   358,
#   807,
#   173,
#   426,
#   134,
#   192,
#   383,
#   516,
#   180,
#   708,
#   40,
#   71,
#   529,
#   535,
#   685,
#   78,
#   476,
#   414,
#   280,
#   414,
#   33,
#   321,
#   223,
#   51,
#   262,
#   240,
#   256,
#   225,
#   91,
#   239,
#   503,
#   282,
#   183,
#   153,
#   167,
#   233,
#   410,
#   161,
#   270,
#   245,
#   282,
#   82,
#   198,
#   327,
#   271,
#   514,
#   83,
#   127,
#   1161,
#   290,
#   651,
#   805,
#   230,
#   110,
#   368,
#   324,
#   222,
#   40,
#   269,
#   252,
#   102,
#   255,
#   473,
#   621,
#   195,
#   1447,
#   118,
#   456,
#   461,
#   48,
#   119,
#   248,
#   944,
#   424,
#   304,
#   630,
#   135,
#   278,
#   125,
#   361,
#   458,
#   464,
#   647,
#   672,
#   305,
#   137,
#   501,
#   329,
#   529,
#   402,
#   55,
#   170,
#   607,
#   256,
#   160,
#   256,
#   104,
#   62,
#   147,
#   118,
#   334,
#   103,
#   315,
#   106,
#   978,
#   208,
#   112,
#   434,
#   521,
#   169,
#   843,
#   180,
#   129,
#   455,
#   137,
#   162,
#   526,
#   328,
#   338,
#   635,
#   137,
#   191,
#   531,
#   558,
#   208,
#   77,
#   575,
#   148,
#   205,
#   137,
#   569,
#   325,
#   224,
#   91,
#   222,
#   47,
#   117,
#   207,
#   368,
#   145,
#   276,
#   49,
#   853,
#   80])
